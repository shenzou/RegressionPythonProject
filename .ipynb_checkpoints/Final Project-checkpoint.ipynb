# %%
# !sudo pip3 install pandas
# !sudo pip3 install sklearn
# Out:
# Identified face as alexandre
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (0.25.3)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.17.4)
# Requirement already satisfied: pytz>=2017.2 in /usr/lib/python3/dist-packages (from pandas) (2019.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/lib/python3/dist-packages (from pandas) (2.7.3)
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Identified face as alexandre
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn) (0.22.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.17.4)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.3.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (0.14.1)
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd

# %% [markdown]
# # I. Traitement des données

# %% [markdown]
# ### 1. Importation du dataset contenant les données débloatées
# (Plusieurs colonnes normalisées (caller_id, opened_by, sys_created_by, sys_updated_by, location, category, subcategory, u_symptom, cmdb_ci, assignement_group, assigned_to, problem_id, rfc, vendor, closed_code, resolved_by ne contiennent plus que des valeurs numériques, sans perte d'information). Les "?" ont été remplacés par des cases vides.
# De plus, les variables de type object ou string ont été converties en float ou int, suivant le cas.

# %%
#La colonne "caused_by" a été supprimée car vide
dataset = pd.read_csv("incident_event_log_debloated.csv", sep=',', encoding='UTF-8')
dataset
# Out:
#             number incident_state  active  reassignment_count  reopen_count  \
# 0       INC0000045            New    True                   0             0
# 1       INC0000045       Resolved    True                   0             0
# 2       INC0000045       Resolved    True                   0             0
# 3       INC0000045         Closed   False                   0             0
# 4       INC0000047            New    True                   0             0
# ...            ...            ...     ...                 ...           ...
# 141707  INC0120835         Closed   False                   1             0
# 141708  INC0121064         Active    True                   0             0
# 141709  INC0121064         Active    True                   1             0
# 141710  INC0121064       Resolved    True                   1             0
# 141711  INC0121064         Closed   False                   1             0
#
#         sys_mod_count  made_sla  caller_id  opened_by        opened_at  ...  \
# 0                   0      True     2403.0        8.0  29/2/2016 01:16  ...
# 1                   2      True     2403.0        8.0  29/2/2016 01:16  ...
# 2                   3      True     2403.0        8.0  29/2/2016 01:16  ...
# 3                   4      True     2403.0        8.0  29/2/2016 01:16  ...
# 4                   0      True     2403.0      397.0  29/2/2016 04:40  ...
# ...               ...       ...        ...        ...              ...  ...
# 141707              4      True      116.0       12.0  16/2/2017 09:09  ...
# 141708              0      True      116.0       12.0  16/2/2017 14:17  ...
# 141709              1      True      116.0       12.0  16/2/2017 14:17  ...
# 141710              2      True      116.0       12.0  16/2/2017 14:17  ...
# 141711              3      True      116.0       12.0  16/2/2017 14:17  ...
#
#         knowledge u_priority_confirmation         notify problem_id  rfc  \
# 0            True                   False  Do Not Notify        NaN  NaN
# 1            True                   False  Do Not Notify        NaN  NaN
# 2            True                   False  Do Not Notify        NaN  NaN
# 3            True                   False  Do Not Notify        NaN  NaN
# 4            True                   False  Do Not Notify        NaN  NaN
# ...           ...                     ...            ...        ...  ...
# 141707      False                    True  Do Not Notify        NaN  NaN
# 141708      False                   False  Do Not Notify        NaN  NaN
# 141709      False                   False  Do Not Notify        NaN  NaN
# 141710      False                    True  Do Not Notify        NaN  NaN
# 141711      False                    True  Do Not Notify        NaN  NaN
#
#         vendor  closed_code  resolved_by      resolved_at        closed_at
# 0          NaN          5.0        149.0  29/2/2016 11:29   5/3/2016 12:00
# 1          NaN          5.0        149.0  29/2/2016 11:29   5/3/2016 12:00
# 2          NaN          5.0        149.0  29/2/2016 11:29   5/3/2016 12:00
# 3          NaN          5.0        149.0  29/2/2016 11:29   5/3/2016 12:00
# 4          NaN          5.0         81.0   1/3/2016 09:52   6/3/2016 10:00
# ...        ...          ...          ...              ...              ...
# 141707     NaN          9.0          9.0  16/2/2017 09:53  16/2/2017 09:53
# 141708     NaN          6.0          9.0  16/2/2017 16:38  16/2/2017 16:38
# 141709     NaN          6.0          9.0  16/2/2017 16:38  16/2/2017 16:38
# 141710     NaN          6.0          9.0  16/2/2017 16:38  16/2/2017 16:38
# 141711     NaN          6.0          9.0  16/2/2017 16:38  16/2/2017 16:38
#
# [141712 rows x 35 columns]

# %%
dataset.dtypes
# Out:
# number                      object
# incident_state              object
# active                        bool
# reassignment_count           int64
# reopen_count                 int64
# sys_mod_count                int64
# made_sla                      bool
# caller_id                  float64
# opened_by                  float64
# opened_at                   object
# sys_created_by             float64
# sys_created_at              object
# sys_updated_by               int64
# sys_updated_at              object
# contact_type                object
# location                   float64
# category                   float64
# subcategory                float64
# u_symptom                  float64
# cmdb_ci                    float64
# impact                      object
# urgency                     object
# priority                    object
# assignment_group           float64
# assigned_to                float64
# knowledge                     bool
# u_priority_confirmation       bool
# notify                      object
# problem_id                 float64
# rfc                         object
# vendor                      object
# closed_code                float64
# resolved_by                float64
# resolved_at                 object
# closed_at                   object
# dtype: object

# %% [markdown]
# ### 2. Conversion des types de données erronés
# On va supprimer certaines colonnes qui sont inutiles pour notre régression, comme l'ID de l'incident et le RFC.
# Pandas a également mal interprété le type de données de certaines colonnes, on applique donc une correction.

# %%
dataset = dataset.drop(columns="number")
dataset = dataset.drop(columns="rfc")
dataset.active = dataset.active.astype(int)
dataset.made_sla = dataset.made_sla.astype(int)
print(dataset.incident_state.value_counts())
incident_state_dico = {"New":0, "Resolved":1, "Closed":2, "Active":3, "Awaiting User Info":4, "Awaiting Vendor":5, "Awaiting Problem":6, "Awaiting Evidence":7, "-100":8}
# Out:
# Active                38716
# New                   36407
# Resolved              25751
# Closed                24985
# Awaiting User Info    14642
# Awaiting Vendor         707
# Awaiting Problem        461
# Awaiting Evidence        38
# -100                      5
# Name: incident_state, dtype: int64

# %%
#dataset.replace({"incident_state": incident_state_dico})
dataset.incident_state = dataset.incident_state.map(incident_state_dico)

# %%
print(dataset.contact_type.value_counts())
contact_type_dico = {"Phone":0, "Self service":1, "Email":2, "IVR":3, "Direct opening":4}
dataset.contact_type = dataset.contact_type.map(contact_type_dico)
dataset.contact_type
# Out:
# Phone             140462
# Self service         995
# Email                220
# IVR                   18
# Direct opening        17
# Name: contact_type, dtype: int64
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 141707    2
# 141708    2
# 141709    2
# 141710    2
# 141711    2
# Name: contact_type, Length: 141712, dtype: int64

# %%
print(dataset.impact.value_counts())
impact_dico = {"2 - Medium":2, "3 - Low":3, "1 - High":1}
dataset.impact = dataset.impact.map(impact_dico)
dataset.urgency = dataset.urgency.map(impact_dico)
# Out:
# 2 - Medium    134335
# 3 - Low         3886
# 1 - High        3491
# Name: impact, dtype: int64

# %%
print(dataset.priority.value_counts())
priority_dico = {"3 - Moderate":3, "4 - Low":4, "2 - High":2, "1 - Critical":1}
dataset.priority = dataset.priority.map(priority_dico)
# Out:
# 3 - Moderate    132452
# 4 - Low           4030
# 2 - High          2972
# 1 - Critical      2258
# Name: priority, dtype: int64

# %%
dataset.knowledge = dataset.knowledge.astype(int)
dataset.u_priority_confirmation = dataset.u_priority_confirmation.astype(int)

# %%
print(dataset.notify.value_counts())
notify_dico = {"Do Not Notify":0, "Send Email":1}
dataset.notify = dataset.notify.map(notify_dico)
# Out:
# Do Not Notify    141593
# Send Email          119
# Name: notify, dtype: int64

# %%
print(dataset.vendor.value_counts())
vendor_dico = {"8s":0, "Vendor 1":1, "Vendor 2":2, "Vendor 3":3}
dataset.vendor = dataset.vendor.map(vendor_dico)
# Out:
# 8s          167
# Vendor 1     69
# Vendor 3      6
# Vendor 2      2
# Name: vendor, dtype: int64

# %%
dataset.dtypes
# Out:
# incident_state               int64
# active                       int64
# reassignment_count           int64
# reopen_count                 int64
# sys_mod_count                int64
# made_sla                     int64
# caller_id                  float64
# opened_by                  float64
# opened_at                   object
# sys_created_by             float64
# sys_created_at              object
# sys_updated_by               int64
# sys_updated_at              object
# contact_type                 int64
# location                   float64
# category                   float64
# subcategory                float64
# u_symptom                  float64
# cmdb_ci                    float64
# impact                       int64
# urgency                      int64
# priority                     int64
# assignment_group           float64
# assigned_to                float64
# knowledge                    int64
# u_priority_confirmation      int64
# notify                       int64
# problem_id                 float64
# vendor                     float64
# closed_code                float64
# resolved_by                float64
# resolved_at                 object
# closed_at                   object
# dtype: object

# %%
dataset.shape
# Out:
# (141712, 33)

# %% [markdown]
# ### 3. On cherche le temps de résolution pour chaque ligne
# Pour chaque ligne, on calcule la différence de temps entre la résolution et l'ouverture de l'incident. Ces informations sont rangées dans une liste de la même longueur que le dataset.

# %%
Y_list = list()
def resolved_time(row):    
    cols = ['opened_at','closed_at']
    #cols = ['opened_at','resolved_at']
    opened_at = pd.to_datetime(row[cols[0]])
00'),
#  Timedelta('299 days 00:30:00'),
#  Timedelta('299 days 00:30:00'),
#  Timedelta('299 days 00:30:00'),
#  Timedelta('299 days 00:30:00'),
#  Timedelta('299 days 00:30:00'),
#  Timedelta('94 days 23:27:00'),
#  Timedelta('94 days 23:27:00'),
#  Timedelta('94 days 23:27:00'),
#  Timedelta('94 days 23:27:00'),
#  Timedelta('24 days 04:03:00'),
#  Timedelta('24 days 04:03:00'),
#  Timedelta('24 days 04:03:00'),
#  Timedelta('24 days 04:03:00'),
#  Timedelta('24 days 04:03:00'),
#  Timedelta('24 days 04:03:00'),
#  Timedelta('61 days 02:27:00'),
#  Timedelta('61 days 02:27:00'),
#  Timedelta('61 days 02:27:00'),
#  Timedelta('61 days 02:27:00'),
#  Timedelta('61 days 02:27:00'),
#  Timedelta('61 days 02:27:00'),
#  Timedelta('-26 days +23:16:00'),
#  Timedelta('-26 days +23:16:00'),
#  Timedelta('-26 days +23:16:00'),
#  Timedelta('-26 days +23:16:00'),
#  Timedelta('-26 days +23:16:00'),
#  Timedelta('-26 days +23:16:00'),
#  Timedelta('125 days 01:16:00'),
#  Timedelta('125 days 01:16:00'),
#  Timedelta('125 days 01:16:00'),
#  Timedelta('125 days 01:16:00'),
#  Timedelta('125 days 01:16:00'),
#  Timedelta('64 days 00:15:00'),
#  Timedelta('64 days 00:15:00'),
#  Timedelta('112 days 19:13:00'),
#  Timedelta('112 days 19:13:00'),
#  Timedelta('112 days 19:13:00'),
#  Timedelta('112 days 19:13:00'),
#  Timedelta('112 days 19:13:00'),
#  Timedelta('24 days 04:10:00'),
#  Timedelta('24 days 04:10:00'),
#  Timedelta('24 days 04:10:00'),
#  Timedelta('24 days 04:10:00'),
#  Timedelta('24 days 04:09:00'),
#  Timedelta('24 days 04:09:00'),
#  Timedelta('24 days 04:09:00'),
#  Timedelta('24 days 04:09:00'),
#  Timedelta('24 days 04:09:00'),
#  Timedelta('24 days 04:09:00'),
#  Timedelta('24 days 04:09:00'),
#  Timedelta('24 days 04:09:00'),
#  Timedelta('24 days 04:09:00'),
#  Timedelta('24 days 04:09:00'),
#  Timedelta('24 days 04:09:00'),
#  Timedelta('24 days 04:09:00'),
#  Timedelta('24 days 04:09:00'),
#  Timedelta('24 days 04:09:00'),
#  Timedelta('24 days 04:09:00'),
#  Timedelta('24 days 04:09:00'),
#  Timedelta('24 days 04:07:00'),
#  Timedelta('24 days 04:07:00'),
#  Timedelta('24 days 04:07:00'),
#  Timedelta('24 days 04:07:00'),
#  Timedelta('24 days 04:07:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('35 days 19:11:00'),
#  Timedelta('35 days 19:11:00'),
#  Timedelta('35 days 19:11:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('24 days 03:47:00'),
#  Timedelta('36 days 22:00:00'),
#  Timedelta('36 days 22:00:00'),
#  Timedelta('36 days 22:00:00'),
#  Timedelta('217 days 23:49:00'),
#  ...]

# %% [markdown]
# ### 4. On controle s'il y a des valeurs négatives. Nous allons donc remplacer ces valeurs négatives par "-1" afin d'avoir des données logiques.

# %%
import numpy as np
import datetime
minutesList = list()
length = len(dataset) 
for i in range(length):
    if Y_list[i] > datetime.timedelta(seconds=0):
        minutesList.append(Y_list[i].total_seconds()/60)
    else:
        minutesList.append(-1)

duration = np.ravel(pd.DataFrame(minutesList))
duration[:20]
dataset["resolved_in"] = duration

# %%
dataset.dtypes
# Out:
# incident_state               int64
# active                       int64
# reassignment_count           int64
# reopen_count                 int64
# sys_mod_count                int64
# made_sla                     int64
# caller_id                  float64
# opened_by                  float64
# opened_at                   object
# sys_created_by             float64
# sys_created_at              object
# sys_updated_by               int64
# sys_updated_at              object
# contact_type                 int64
# location                   float64
# category                   float64
# subcategory                float64
# u_symptom                  float64
# cmdb_ci                    float64
# impact                       int64
# urgency                      int64
# priority                     int64
# assignment_group           float64
# assigned_to                float64
# knowledge                    int64
# u_priority_confirmation      int64
# notify                       int64
# problem_id                 float64
# vendor                     float64
# closed_code                float64
# resolved_by                float64
# resolved_at                 object
# closed_at                   object
# resolved_in                float64
# dtype: object

# %% [markdown]
# ### 5. On garde seulement les incidents ayant pour statut "Resolved"

# %%
resolved_temp = dataset.loc[dataset.incident_state == 1]
dataset = pd.DataFrame(resolved_temp)
dataset = dataset.reset_index(drop=True)

# %% [markdown]
# On garde seulement les lignes ayant une valeur correcte pour resolved_in

# %%
resolved_temp = dataset.loc[dataset.resolved_in != -1]
dataset = pd.DataFrame(resolved_temp)
dataset = dataset.reset_index(drop=True)

# %%
dataset
# Out:
#        incident_state  active  reassignment_count  reopen_count  \
# 0                   1       1                   0             0
# 1                   1       1                   0             0
# 2                   1       1                   1             0
# 3                   1       1                   0             0
# 4                   1       1                   0             0
# ...               ...     ...                 ...           ...
# 16823               1       1                   1             0
# 16824               1       1                   3             0
# 16825               1       1                   0             0
# 16826               1       1                   1             0
# 16827               1       1                   1             0
#
#        sys_mod_count  made_sla  caller_id  opened_by        opened_at  \
# 0                  2         1     2403.0        8.0  29/2/2016 01:16
# 1                  3         1     2403.0        8.0  29/2/2016 01:16
# 2                  7         1     2403.0      397.0  29/2/2016 04:40
# 3                  5         1     4416.0        8.0  29/2/2016 06:10
# 4                  2         1     4491.0      180.0  29/2/2016 06:38
# ...              ...       ...        ...        ...              ...
# 16823              2         1      116.0       12.0  10/2/2017 14:11
# 16824              5         1     5100.0      490.0  13/2/2017 10:33
# 16825              1         1       90.0        8.0  15/2/2017 02:02
# 16826              3         1      116.0       12.0  16/2/2017 09:09
# 16827              2         1      116.0       12.0  16/2/2017 14:17
#
#        sys_created_by  ... knowledge  u_priority_confirmation notify  \
# 0                 6.0  ...         1                        0      0
# 1                 6.0  ...         1                        0      0
# 2               171.0  ...         1                        0      0
# 3                 NaN  ...         1                        0      0
# 4                81.0  ...         1                        0      0
# ...               ...  ...       ...                      ...    ...
# 16823             NaN  ...         0                        1      0
# 16824             NaN  ...         0                        1      0
# 16825             NaN  ...         0                        1      0
# 16826             NaN  ...         0                        1      0
# 16827             NaN  ...         0                        1      0
#
#        problem_id  vendor  closed_code  resolved_by      resolved_at  \
# 0             NaN     NaN          5.0        149.0  29/2/2016 11:29
# 1             NaN     NaN          5.0        149.0  29/2/2016 11:29
# 2             NaN     NaN          5.0         81.0   1/3/2016 09:52
# 3             2.0     NaN         10.0          5.0   1/3/2016 02:55
# 4             NaN     NaN          3.0        113.0   2/3/2016 12:06
# ...           ...     ...          ...          ...              ...
# 16823         NaN     NaN          6.0          9.0  10/2/2017 17:27
# 16824         NaN     NaN          6.0        166.0  14/2/2017 09:37
# 16825         NaN     NaN          6.0          5.0  17/2/2017 00:47
# 16826         NaN     NaN          9.0          9.0  16/2/2017 09:53
# 16827         NaN     NaN          6.0          9.0  16/2/2017 16:38
#
#              closed_at  resolved_in
# 0       5/3/2016 12:00      92804.0
# 1       5/3/2016 12:00      92804.0
# 2       6/3/2016 10:00     137120.0
# 3       6/3/2016 03:00     136610.0
# 4       7/3/2016 13:00     180382.0
# ...                ...          ...
# 16823  10/2/2017 17:27        196.0
# 16824  14/2/2017 12:08       1535.0
# 16825  17/2/2017 00:50       2808.0
# 16826  16/2/2017 09:53         44.0
# 16827  16/2/2017 16:38        141.0
#
# [16828 rows x 34 columns]

# %% [markdown]
# Après avoir trouvé ces temps, on va convertir les colonnes de type date (en string) en float.

# %%
dataset.opened_at = dataset.opened_at.str.replace("/","")
dataset.sys_created_at = dataset.sys_created_at.str.replace("/","")
dataset.sys_updated_at = dataset.sys_updated_at.str.replace("/","")
dataset.resolved_at = dataset.resolved_at.str.replace("/","")
dataset.closed_at = dataset.closed_at.str.replace("/","")

dataset.opened_at = dataset.opened_at.str.replace(" ","")
dataset.sys_created_at = dataset.sys_created_at.str.replace(" ","")
dataset.sys_updated_at = dataset.sys_updated_at.str.replace(" ","")
dataset.resolved_at = dataset.resolved_at.str.replace(" ","")
dataset.closed_at = dataset.closed_at.str.replace(" ","")

dataset.opened_at = dataset.opened_at.str.replace(":","")
dataset.sys_created_at = dataset.sys_created_at.str.replace(":","")
dataset.sys_updated_at = dataset.sys_updated_at.str.replace(":","")
dataset.resolved_at = dataset.resolved_at.str.replace(":","")
dataset.closed_at = dataset.closed_at.str.replace(":","")

dataset.opened_at = dataset.opened_at.astype(float)
dataset.sys_created_at = dataset.sys_created_at.astype(float)
dataset.sys_updated_at = dataset.sys_updated_at.astype(float)
dataset.resolved_at = dataset.resolved_at.astype(float)
dataset.closed_at = dataset.closed_at.astype(float)

# %% [markdown]
# ### 6. On regarde si certaines colonnes ont trop de valeurs manquantes (et ne sont donc pas utilisables). Si plus de 30% des données de la colonne sont manquantes, on la supprime.

# %%
import math
total = len(dataset["incident_state"])
#print(dataset["vendor"][3])
for column in dataset.columns:
    v = 0
    for i in range(total):
        if dataset[column][i] == None:
            v+=1
        elif dataset[column].dtype == int or dataset[column].dtype == float:
            if math.isnan(dataset[column][i]):
                v+=1
    if v/total*100 > 30:
        print("Column name: ", column, " ; Empty: ", v/total*100, "%")
        dataset = dataset.drop(columns=column)
dataset.dtypes
# Out:
# Column name:  sys_created_by  ; Empty:  46.678155455193725 %
# Column name:  sys_created_at  ; Empty:  46.678155455193725 %
# Column name:  cmdb_ci  ; Empty:  99.8098407416211 %
# Column name:  problem_id  ; Empty:  98.19942952222488 %
# Column name:  vendor  ; Empty:  99.92274780128358 %
# incident_state               int64
# active                       int64
# reassignment_count           int64
# reopen_count                 int64
# sys_mod_count                int64
# made_sla                     int64
# caller_id                  float64
# opened_by                  float64
# opened_at                  float64
# sys_updated_by               int64
# sys_updated_at             float64
# contact_type                 int64
# location                   float64
# category                   float64
# subcategory                float64
# u_symptom                  float64
# impact                       int64
# urgency                      int64
# priority                     int64
# assignment_group           float64
# assigned_to                float64
# knowledge                    int64
# u_priority_confirmation      int64
# notify                       int64
# closed_code                float64
# resolved_by                float64
# resolved_at                float64
# closed_at                  float64
# resolved_in                float64
# dtype: object

# %% [markdown]
# # II. Régressions

# %% [markdown]
# ### 1. Si on a des valeurs infinies dans le dataset, elles sont remplacées par NaN. Ensuite, les valeurs NaN du dataset sont remplacées par une moyenne.

# %%
dataset[dataset==np.inf]=np.nan
dataset.fillna(dataset.mean(), inplace=True)

# %%
dataset
# Out:
#        incident_state  active  reassignment_count  reopen_count  \
# 0                   1       1                   0             0
# 1                   1       1                   0             0
# 2                   1       1                   1             0
# 3                   1       1                   0             0
# 4                   1       1                   0             0
# ...               ...     ...                 ...           ...
# 16823               1       1                   1             0
# 16824               1       1                   3             0
# 16825               1       1                   0             0
# 16826               1       1                   1             0
# 16827               1       1                   1             0
#
#        sys_mod_count  made_sla  caller_id  opened_by     opened_at  \
# 0                  2         1     2403.0        8.0  2.922016e+10
# 1                  3         1     2403.0        8.0  2.922016e+10
# 2                  7         1     2403.0      397.0  2.922016e+10
# 3                  5         1     4416.0        8.0  2.922016e+10
# 4                  2         1     4491.0      180.0  2.922016e+10
# ...              ...       ...        ...        ...           ...
# 16823              2         1      116.0       12.0  1.022017e+10
# 16824              5         1     5100.0      490.0  1.322017e+10
# 16825              1         1       90.0        8.0  1.522017e+10
# 16826              3         1      116.0       12.0  1.622017e+10
# 16827              2         1      116.0       12.0  1.622017e+10
#
#        sys_updated_by  ...  assignment_group  assigned_to  knowledge  \
# 0                 642  ...              56.0   100.542242          1
# 1                 804  ...              56.0   100.542242          1
# 2                 332  ...              24.0    89.000000          1
# 3                  21  ...              70.0     6.000000          1
# 4                 465  ...              25.0   125.000000          1
# ...               ...  ...               ...          ...        ...
# 16823              27  ...              31.0    10.000000          0
# 16824             699  ...              39.0    36.000000          0
# 16825              21  ...              64.0     6.000000          0
# 16826              27  ...              31.0    10.000000          0
# 16827              27  ...              31.0    10.000000          0
#
#        u_priority_confirmation  notify  closed_code  resolved_by  \
# 0                            0       0          5.0        149.0
# 1                            0       0          5.0        149.0
# 2                            0       0          5.0         81.0
# 3                            0       0         10.0          5.0
# 4                            0       0          3.0        113.0
# ...                        ...     ...          ...          ...
# 16823                        1       0          6.0          9.0
# 16824                        1       0          6.0        166.0
# 16825                        1       0          6.0          5.0
# 16826                        1       0          9.0          9.0
# 16827                        1       0          6.0          9.0
#
#         resolved_at     closed_at  resolved_in
# 0      2.922016e+10  5.320161e+09      92804.0
# 1      2.922016e+10  5.320161e+09      92804.0
# 2      1.320161e+09  6.320161e+09     137120.0
# 3      1.320160e+09  6.320160e+09     136610.0
# 4      2.320161e+09  7.320161e+09     180382.0
# ...             ...           ...          ...
# 16823  1.022017e+10  1.022017e+10        196.0
# 16824  1.422017e+10  1.422017e+10       1535.0
# 16825  1.722017e+10  1.722017e+10       2808.0
# 16826  1.622017e+10  1.622017e+10         44.0
# 16827  1.622017e+10  1.622017e+10        141.0
#
# [16828 rows x 29 columns]

# %% [markdown]
# ### 2. On crée nos X et Y en supprimant les colonnes nécessaires

# %%
y = dataset.resolved_in
x = dataset.drop('resolved_in', axis=1)
x = x.drop('resolved_at', axis=1)
x = x.drop('closed_at', axis=1)

# %%
x
# Out:
#        incident_state  active  reassignment_count  reopen_count  \
# 0                   1       1                   0             0
# 1                   1       1                   0             0
# 2                   1       1                   1             0
# 3                   1       1                   0             0
# 4                   1       1                   0             0
# ...               ...     ...                 ...           ...
# 16823               1       1                   1             0
# 16824               1       1                   3             0
# 16825               1       1                   0             0
# 16826               1       1                   1             0
# 16827               1       1                   1             0
#
#        sys_mod_count  made_sla  caller_id  opened_by     opened_at  \
# 0                  2         1     2403.0        8.0  2.922016e+10
# 1                  3         1     2403.0        8.0  2.922016e+10
# 2                  7         1     2403.0      397.0  2.922016e+10
# 3                  5         1     4416.0        8.0  2.922016e+10
# 4                  2         1     4491.0      180.0  2.922016e+10
# ...              ...       ...        ...        ...           ...
# 16823              2         1      116.0       12.0  1.022017e+10
# 16824              5         1     5100.0      490.0  1.322017e+10
# 16825              1         1       90.0        8.0  1.522017e+10
# 16826              3         1      116.0       12.0  1.622017e+10
# 16827              2         1      116.0       12.0  1.622017e+10
#
#        sys_updated_by  ...  impact  urgency  priority  assignment_group  \
# 0                 642  ...       2        2         3              56.0
# 1                 804  ...       2        2         3              56.0
# 2                 332  ...       2        2         3              24.0
# 3                  21  ...       2        2         3              70.0
# 4                 465  ...       2        2         3              25.0
# ...               ...  ...     ...      ...       ...               ...
# 16823              27  ...       2        2         3              31.0
# 16824             699  ...       2        2         3              39.0
# 16825              21  ...       2        2         3              64.0
# 16826              27  ...       2        2         3              31.0
# 16827              27  ...       2        2         3              31.0
#
#        assigned_to  knowledge  u_priority_confirmation  notify  closed_code  \
# 0       100.542242          1                        0       0          5.0
# 1       100.542242          1                        0       0          5.0
# 2        89.000000          1                        0       0          5.0
# 3         6.000000          1                        0       0         10.0
# 4       125.000000          1                        0       0          3.0
# ...            ...        ...                      ...     ...          ...
# 16823    10.000000          0                        1       0          6.0
# 16824    36.000000          0                        1       0          6.0
# 16825     6.000000          0                        1       0          6.0
# 16826    10.000000          0                        1       0          9.0
# 16827    10.000000          0                        1       0          6.0
#
#        resolved_by
# 0            149.0
# 1            149.0
# 2             81.0
# 3              5.0
# 4            113.0
# ...            ...
# 16823          9.0
# 16824        166.0
# 16825          5.0
# 16826          9.0
# 16827          9.0
#
# [16828 rows x 26 columns]

# %% [markdown]
# ### 3. On sépare nos données en un dataset de train et de test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x,y,test_size=0.2, random_state=0)
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((13462, 26), (3366, 26), (13462,), (3366,))

# %% [markdown]
# ### 4. On réinitialise les index de test afin de pouvoir avoir des plots propres

# %%
X_test = X_test.reset_index(drop=True)
Y_test = Y_test.reset_index(drop=True)

# %%
X_train.dtypes
# Out:
# incident_state               int64
# active                       int64
# reassignment_count           int64
# reopen_count                 int64
# sys_mod_count                int64
# made_sla                     int64
# caller_id                  float64
# opened_by                  float64
# opened_at                  float64
# sys_updated_by               int64
# sys_updated_at             float64
# contact_type                 int64
# location                   float64
# category                   float64
# subcategory                float64
# u_symptom                  float64
# impact                       int64
# urgency                      int64
# priority                     int64
# assignment_group           float64
# assigned_to                float64
# knowledge                    int64
# u_priority_confirmation      int64
# notify                       int64
# closed_code                float64
# resolved_by                float64
# dtype: object

# %%
from sklearn.ensemble import RandomForestRegressor



randomForestRegressor = RandomForestRegressor(n_estimators=150,random_state=100)
randomForestRegressor.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=150, n_jobs=None, oob_score=False,
#                       random_state=100, verbose=0, warm_start=False)

# %%
importances = pd.Series(randomForestRegressor.feature_importances_, index=X_train.columns)
importances.nlargest(20).plot(kind='barh')

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor

regressor = DecisionTreeRegressor()
#cross_val_score(regressor, X_train, Y_train, cv=10)
regressor.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
importances = pd.Series(regressor.feature_importances_, index=X_train.columns)
importances.nlargest(20).plot(kind='barh')

# %% [markdown]
# ### On optimise le score

# %%
bestScore = regressor
i = 0
while i < 1000:
    regressor.fit(X_train, Y_train)
    if regressor.score(X_test, Y_test) > bestScore.score(X_test, Y_test) :
        bestScore = regressor
    i+=1
bestScore.score(X_test, Y_test)
# Out:
# 0.9122010537695795

# %%
regressor = bestScore

# %%
y_pred = regressor.predict(X_test)

# %%
df=pd.DataFrame({'Actual':Y_test, 'Predicted':y_pred})
df
# Out:
#         Actual  Predicted
# 0      94286.0    93836.0
# 1     217522.0   217515.0
# 2       8574.0     8679.0
# 3     220385.0   220385.0
# 4     220377.0   220344.0
# ...        ...        ...
# 3361   29037.0    27515.0
# 3362    8880.0     8733.0
# 3363  265188.0   264923.0
# 3364  220353.0   220332.0
# 3365   30547.0    25784.0
#
# [3366 rows x 2 columns]

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(Y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, y_pred)))
# Out:
# Mean Absolute Error: 7620.140184464175
# Mean Squared Error: 1075294273.2449095
# Root Mean Squared Error: 32791.679939352136

# %%
X_test
# Out:
#       incident_state  active  reassignment_count  reopen_count  sys_mod_count  \
# 0                  1       1                   1             0              2
# 1                  1       1                   0             0              2
# 2                  1       1                   1             0              7
# 3                  1       1                   0             0              1
# 4                  1       1                   1             0              1
# ...              ...     ...                 ...           ...            ...
# 3361               1       1                   6             0             15
# 3362               1       1                   1             0              2
# 3363               1       1                   1             0              2
# 3364               1       1                   0             0              1
# 3365               1       1                   1             0             13
#
#       made_sla  caller_id  opened_by     opened_at  sys_updated_by  ...  \
# 0            1     3760.0       94.0  3.132016e+10             469  ...
# 1            1     4514.0      444.0  2.320162e+09             811  ...
# 2            1     3466.0      390.0  2.132016e+10             695  ...
# 3            1     5372.0       17.0  7.420161e+09              44  ...
# 4            1     2513.0       17.0  6.420161e+09              44  ...
# ...        ...        ...        ...           ...             ...  ...
# 3361         1     1663.0       17.0  2.642016e+10             967  ...
# 3362         1     3330.0      131.0  1.652016e+10             357  ...
# 3363         1     4710.0      131.0  3.320161e+09             718  ...
# 3364         1     1193.0       17.0  4.420161e+09              44  ...
# 3365         1     3634.0       40.0  2.742016e+10             928  ...
#
#       impact  urgency  priority  assignment_group  assigned_to  knowledge  \
# 0          2        2         3         70.000000   128.000000          0
# 1          2        2         3         51.973503   100.542242          1
# 2          2        2         3         31.000000   182.000000          0
# 3          2        2         3         70.000000    13.000000          0
# 4          2        2         3         70.000000    13.000000          0
# ...      ...      ...       ...               ...          ...        ...
# 3361       2        2         3          6.000000   247.000000          0
# 3362       2        2         3         13.000000    96.000000          0
# 3363       3        3         4         30.000000   100.542242          1
# 3364       2        2         3         70.000000    13.000000          0
# 3365       2        2         3         28.000000   236.000000          0
#
#       u_priority_confirmation  notify  closed_code  resolved_by
# 0                           1       0          6.0        116.0
# 1                           0       0          1.0        190.0
# 2                           1       0          9.0        165.0
# 3                           1       0          7.0         11.0
# 4                           1       0          7.0         11.0
# ...                       ...     ...          ...          ...
# 3361                        1       0          6.0        226.0
# 3362                        1       0          8.0         86.0
# 3363                        0       0          6.0        167.0
# 3364                        1       0          7.0         11.0
# 3365                        1       0          6.0        215.0
#
# [3366 rows x 26 columns]

# %%
import matplotlib.pyplot as plt 


X_t = np.arange(0.0, 5.0, 0.01)[:, np.newaxis]

plt.scatter(X_test.index, Y_test, color = 'red')
plt.plot(X_test.index, regressor.predict(X_test), color = 'blue')
#plt.plot(X_test, Y_test, color="black", label="real values", linewidth=1)
#plt.plot(X_test, ypred, color="cornflowerblue",
#         label="max_depth=2", linewidth=2)
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %%
import matplotlib.pyplot as plt 

plt.figure()
plt.scatter(X_test.index[:500], Y_test[:500], s=20, edgecolor="black",
            c="darkorange", label="original data")
plt.plot(X_test.index[:500], y_pred[:500], color="cornflowerblue",
         label="prediction", linewidth=1)
plt.xlabel("data")
plt.ylabel("Resolution time")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()
